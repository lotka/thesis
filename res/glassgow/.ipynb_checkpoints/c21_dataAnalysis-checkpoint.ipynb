# %%
# %matplotlib inline
import sys
import os 
sys.path.append('/home/luka/Dropbox/cqp/schmidtLib')
import schmidt as sch
reload(sch)
# Out:
# <module 'schmidt' from '/home/luka/Dropbox/cqp/schmidtLib/schmidt.pyc'>

# %%
directory = 'C17/'
sch.analyseGlassgow(directory,(200,501),(30,302))
# Out:
# Average noise value: 3.46978196024e-09
# SNR: 21.9455304134
# Error is: 0.021583739954
# K = 2.39453240126 P = 0.417618070014
# old axis: [1540.0, 1543.0, 1547.0, 1548.5060000000001](302, 501)
# new axis: [1541.1976047904191, 1543.0, 1547.1496026490067, 1548.5060000000001](272, 301)

# %%
directory = 'C21/'
sch.analyseGlassgow(directory,(180,230),(80,160))
# Out:
# Average noise value: 7.67076888146e-11
# 1.28249736604e-05
# SNR: 31.2276727033
# Error is: 0.021522518147
# K = 1.91707656175 P = 0.521627576045
# old axis: [1540.0, 1543.0, 1547.0, 1548.5060000000001](302, 501)
# new axis: [1541.0778443113772, 1541.377245508982, 1547.398940397351, 1547.797880794702](80, 50)

# %%
directory = 'B32/002_TriedToSym/'
analyseGlassgow(directory,(180,330),(80,160))
# Out:
# 1.68891853049e-09
# (202, 501)
# [1536.0778443113772, 1536.9760479041915, 1542.7984158415843, 1543.1968316831683]

# %%
directory = 'B32/001/'
sch.analyseGlassgow(directory,(180,330),(80,160))
# Out:
# Average noise value: 1.7503739876e-09
# SNR: 4.23279185586
# Error is: 0.0716999093563
# K = 1.60213866166 P = 0.624165700468
# old axis: [1535.0, 1538.0, 1542.4000000000001, 1543.4059999999999](202, 501)
# new axis: [1536.0778443113772, 1536.9760479041915, 1542.7984158415843, 1543.1968316831683](80, 150)

# %%
sys.
